# %%
pip install openai==0.28
# Out:
# Collecting openai==0.28
#   Using cached openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in /opt/anaconda3/lib/python3.11/site-packages (from openai==0.28) (2.32.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from openai==0.28) (4.66.5)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.11/site-packages (from openai==0.28) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20->openai==0.28) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20->openai==0.28) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20->openai==0.28) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (1.9.3)
# Using cached openai-0.28.0-py3-none-any.whl (76 kB)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.47.0
#     Uninstalling openai-1.47.0:
#       Successfully uninstalled openai-1.47.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.1.25 requires openai<2.0.0,>=1.40.0, but you have openai 0.28.0 which is incompatible.
# ragas 0.1.20 requires openai>1, but you have openai 0.28.0 which is incompatible.
# Successfully installed openai-0.28.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from neo4j import GraphDatabase
import json
from openai import OpenAI
import numpy as np
from typing import List
import os
import openai

# Neo4j connection details
URI = "bolt://localhost:7687"
USERNAME = "neo4j"
PASSWORD = "12345678"

client = OpenAI(api_key="")


def embed_text(text: str) -> List[float]:
    response = client.embeddings.create(
        model="text-embedding-3-small",
        input=text
    )
    return response.data[0].embedding


def add_data_to_neo4j(tx, pre_text, post_text, table, id, pre_text_embedding, post_text_embedding):
    query = """
    CREATE (d:Document {id: $id})
    CREATE (p:PreText {content: $pre_text, embedding: $pre_text_embedding})
    CREATE (po:PostText {content: $post_text, embedding: $post_text_embedding})
    CREATE (t:Table {content: $table})
    CREATE (i:ID {value: $id})
    CREATE (d)-[:HAS_PRE_TEXT]->(p)
    CREATE (d)-[:HAS_POST_TEXT]->(po)
    CREATE (d)-[:HAS_TABLE]->(t)
    CREATE (d)-[:HAS_ID]->(i)
    """
    tx.run(query, 
           id=id, 
           pre_text=pre_text, 
           post_text=post_text, 
           table=json.dumps(table),
           pre_text_embedding=pre_text_embedding,
           post_text_embedding=post_text_embedding
    )

def process_json_file(file_path):
    with GraphDatabase.driver(URI, auth=(USERNAME, PASSWORD)) as driver:
        with driver.session() as session:
            with open(file_path, 'r') as file:
                data_list = json.load(file)
                
                for data in data_list:
                    pre_text = " ".join(data['pre_text'])
                    post_text = " ".join(data['post_text'])
                    table = data['table']
                    id = data['id']
                    
                    # Get embeddings
                    pre_text_embedding = embed_text(pre_text)
                    post_text_embedding = embed_text(post_text)
                    
                    # Convert numpy arrays to lists for Neo4j compatibility
                    pre_text_embedding = np.array(pre_text_embedding).tolist()
                    post_text_embedding = np.array(post_text_embedding).tolist()
                    
                    session.execute_write(add_data_to_neo4j, 
                                          pre_text, 
                                          post_text, 
                                          table, 
                                          id, 
                                          pre_text_embedding, 
                                          post_text_embedding)
                    print(f"Added document with ID: {id}")

# Usage
process_json_file('convfinqa_rag/data/train.json')
# Out:
# Added document with ID: Single_JKHY/2009/page_28.pdf-3
# Added document with ID: Single_RSG/2008/page_114.pdf-2
# Added document with ID: Single_AAPL/2002/page_23.pdf-1
# Added document with ID: Single_UPS/2009/page_33.pdf-2
# Added document with ID: Double_UPS/2009/page_33.pdf
# Added document with ID: Single_CE/2010/page_134.pdf-2
# Added document with ID: Single_JPM/2013/page_104.pdf-2
# Added document with ID: Double_MAS/2012/page_92.pdf
# Added document with ID: Single_HIG/2004/page_122.pdf-2
# Added document with ID: Single_SLG/2013/page_133.pdf-4
# Added document with ID: Double_AES/2016/page_98.pdf
# Added document with ID: Single_ETR/2008/page_336.pdf-3
# Added document with ID: Single_BKR/2017/page_105.pdf-2
# Added document with ID: Double_AES/2011/page_230.pdf
# Added document with ID: Single_JPM/2016/page_73.pdf-4
# Added document with ID: Double_ADBE/2018/page_66.pdf
# Added document with ID: Double_PNC/2014/page_99.pdf
# Added document with ID: Single_BLK/2017/page_35.pdf-4
# Added document with ID: Single_HII/2015/page_120.pdf-4
# Added document with ID: Single_AMT/2002/page_104.pdf-2
# Added document with ID: Single_VRTX/2005/page_103.pdf-1
# Added document with ID: Single_STT/2013/page_54.pdf-4
# Added document with ID: Single_GS/2014/page_62.pdf-2
# Added document with ID: Double_GPN/2018/page_85.pdf
# Added document with ID: Double_EW/2016/page_36.pdf
# Added document with ID: Single_ADI/2009/page_90.pdf-3
# Added document with ID: Single_AON/2007/page_185.pdf-4
# Added document with ID: Single_ZBH/2002/page_46.pdf-3
# Added document with ID: Single_HII/2015/page_120.pdf-1
# Added document with ID: Single_AES/2002/page_117.pdf-2
# Added document with ID: Single_ALXN/2016/page_89.pdf-1
# Added document with ID: Single_AON/2018/page_41.pdf-3
# Added document with ID: Single_RSG/2012/page_145.pdf-1
# Added document with ID: Double_CB/2008/page_144.pdf
# Added document with ID: Single_STT/2011/page_94.pdf-3
# Added document with ID: Single_L/2016/page_62.pdf-1
# Added document with ID: Single_JPM/2009/page_206.pdf-3
# Added document with ID: Single_GS/2013/page_47.pdf-2
# Added document with ID: Single_WRK/2019/page_49.pdf-1
# Added document with ID: Single_LMT/2014/page_31.pdf-2
# Added document with ID: Double_NCLH/2017/page_57.pdf
# Added document with ID: Double_WRK/2018/page_53.pdf
# Added document with ID: Single_ORLY/2015/page_28.pdf-4
# Added document with ID: Single_SWKS/2010/page_105.pdf-2
# Added document with ID: Single_MRO/2004/page_57.pdf-4
# Added document with ID: Single_ETR/2011/page_22.pdf-3
# Added document with ID: Single_IP/2007/page_19.pdf-2
# Added document with ID: Single_RCL/2006/page_37.pdf-2
# Added document with ID: Single_MRO/2008/page_135.pdf-1
# Added document with ID: Single_IP/2009/page_36.pdf-1
# Added document with ID: Double_RCL/2013/page_18.pdf
# Added document with ID: Single_AAPL/2010/page_42.pdf-2
# Added document with ID: Double_ADBE/2009/page_98.pdf
# Added document with ID: Single_GPN/2017/page_91.pdf-2
# Added document with ID: Single_RE/2013/page_40.pdf-1
# Added document with ID: Single_IP/2012/page_57.pdf-2
# Added document with ID: Single_ILMN/2006/page_86.pdf-3
# Added document with ID: Double_NKE/2015/page_37.pdf
# Added document with ID: Single_LKQ/2018/page_102.pdf-2
# Added document with ID: Single_DRE/2007/page_39.pdf-4
# Added document with ID: Single_DISCA/2012/page_54.pdf-4
# Added document with ID: Single_MMM/2007/page_38.pdf-2
# Added document with ID: Single_D/2002/page_39.pdf-2
# Added document with ID: Double_TSCO/2017/page_73.pdf
# Added document with ID: Single_ILMN/2006/page_86.pdf-1
# Added document with ID: Single_MRO/2011/page_39.pdf-1
# Added document with ID: Single_LMT/2018/page_29.pdf-1
# Added document with ID: Double_GPN/2007/page_97.pdf
# Added document with ID: Single_CE/2017/page_20.pdf-2
# Added document with ID: Single_RE/2012/page_31.pdf-3
# Added document with ID: Single_UPS/2012/page_51.pdf-1
# Added document with ID: Single_MO/2017/page_10.pdf-4
# Added document with ID: Double_CMCSA/2004/page_30.pdf
# Added document with ID: Single_STT/2014/page_69.pdf-2
# Added document with ID: Single_MRO/2009/page_127.pdf-1
# Added document with ID: Double_AMT/2010/page_111.pdf
# Added document with ID: Double_UAA/2017/page_52.pdf
# Added document with ID: Single_IP/2007/page_30.pdf-2
# Added document with ID: Single_AAL/2015/page_51.pdf-3
# Added document with ID: Double_LKQ/2009/page_77.pdf
# Added document with ID: Single_APD/2019/page_100.pdf-2
# Added document with ID: Single_VLO/2018/page_99.pdf-1
# Added document with ID: Single_CDNS/2018/page_82.pdf-3
# Added document with ID: Single_ETR/2011/page_435.pdf-2
# Added document with ID: Single_IQV/2018/page_59.pdf-2
# Added document with ID: Single_IPG/2014/page_47.pdf-1
# Added document with ID: Single_CE/2012/page_16.pdf-1
# Added document with ID: Single_GPN/2015/page_82.pdf-3
# Added document with ID: Single_IP/2012/page_64.pdf-2
# Added document with ID: Double_DRE/2008/page_49.pdf
# Added document with ID: Single_CDW/2015/page_34.pdf-2
# Added document with ID: Single_LMT/2012/page_44.pdf-2
# Added document with ID: Double_AWK/2013/page_123.pdf
# Added document with ID: Single_FITB/2013/page_163.pdf-3
# Added document with ID: Single_ETR/2004/page_20.pdf-2
# Added document with ID: Double_AAPL/2008/page_52.pdf
# Added document with ID: Single_ETR/2004/page_258.pdf-4
# Added document with ID: Single_NKE/2009/page_81.pdf-1
# Added document with ID: Double_ADBE/2011/page_116.pdf
# Added document with ID: Single_UPS/2010/page_33.pdf-4
# Added document with ID: Single_DISCA/2013/page_60.pdf-2
# Added document with ID: Double_FIS/2016/page_93.pdf
# Added document with ID: Single_CDNS/2012/page_58.pdf-1
# Added document with ID: Single_LMT/2012/page_46.pdf-2
# Added document with ID: Single_UAA/2016/page_82.pdf-2
# Added document with ID: Single_UNP/2018/page_50.pdf-1
# Added document with ID: Double_CAG/2008/page_35.pdf
# Added document with ID: Single_AWK/2012/page_118.pdf-3
# Added document with ID: Single_ORLY/2006/page_40.pdf-2
# Added document with ID: Single_MMM/2005/page_55.pdf-2
# Added document with ID: Double_RSG/2017/page_14.pdf
# Added document with ID: Single_KIM/2008/page_126.pdf-2
# Added document with ID: Single_IPG/2015/page_38.pdf-2
# Added document with ID: Single_BLK/2012/page_32.pdf-4
# Added document with ID: Single_IPG/2014/page_37.pdf-1
# Added document with ID: Single_PNC/2008/page_32.pdf-1
# Added document with ID: Single_IPG/2015/page_24.pdf-2
# Added document with ID: Single_AON/2013/page_54.pdf-4
# Added document with ID: Single_LMT/2012/page_29.pdf-4
# Added document with ID: Single_PNC/2009/page_31.pdf-5
# Added document with ID: Double_MAA/2017/page_89.pdf
# Added document with ID: Single_IPG/2016/page_24.pdf-2
# Added document with ID: Single_WMT/2018/page_46.pdf-4
# Added document with ID: Single_AES/2001/page_42.pdf-3
# Added document with ID: Single_CDNS/2016/page_32.pdf-1
# Added document with ID: Single_ILMN/2008/page_77.pdf-1
# Added document with ID: Double_RE/2014/page_40.pdf
# Added document with ID: Double_HII/2011/page_114.pdf
# Added document with ID: Double_AES/2011/page_131.pdf
# Added document with ID: Single_IPG/2014/page_95.pdf-3
# Added document with ID: Double_ZBH/2002/page_32.pdf
# Added document with ID: Single_DISCA/2008/page_141.pdf-4
# Added document with ID: Single_PPG/2006/page_22.pdf-2
# Added document with ID: Single_CE/2014/page_90.pdf-1
# Added document with ID: Single_DVN/2015/page_117.pdf-2
# Added document with ID: Double_LLY/2018/page_42.pdf
# Added document with ID: Single_ETFC/2007/page_22.pdf-4
# Added document with ID: Single_C/2009/page_195.pdf-2
# Added document with ID: Double_C/2015/page_46.pdf
# Added document with ID: Single_CAT/2017/page_113.pdf-4
# Added document with ID: Single_STT/2009/page_122.pdf-4
# Added document with ID: Single_DG/2008/page_73.pdf-4
# Added document with ID: Single_AMT/2004/page_91.pdf-4
# Added document with ID: Single_AWK/2012/page_12.pdf-2
# Added document with ID: Single_ADI/2011/page_83.pdf-2
# Added document with ID: Double_ETR/2016/page_403.pdf
# Added document with ID: Single_ETR/2017/page_441.pdf-4
# Added document with ID: Single_C/2009/page_141.pdf-4
# Added document with ID: Double_AON/2018/page_90.pdf
# Added document with ID: Single_LMT/2013/page_89.pdf-1
# Added document with ID: Single_IPG/2014/page_95.pdf-1
# Added document with ID: Single_CE/2011/page_17.pdf-3
# Added document with ID: Double_ETR/2008/page_356.pdf
# Added document with ID: Single_IPG/2014/page_47.pdf-3
# Added document with ID: Double_C/2010/page_226.pdf
# Added document with ID: Single_DVN/2014/page_112.pdf-3
# Added document with ID: Single_ETR/2017/page_19.pdf-3
# Added document with ID: Double_AMAT/2017/page_33.pdf
# Added document with ID: Single_STT/2013/page_175.pdf-2
# Added document with ID: Single_AWK/2015/page_106.pdf-2
# Added document with ID: Double_CE/2005/page_167.pdf
# Added document with ID: Single_ECL/2017/page_96.pdf-4
# Added document with ID: Single_TFX/2018/page_74.pdf-1
# Added document with ID: Single_FRT/2009/page_124.pdf-1
# Added document with ID: Single_AMT/2005/page_84.pdf-1
# Added document with ID: Single_HII/2011/page_60.pdf-1
# Added document with ID: Double_C/2008/page_212.pdf
# Added document with ID: Single_C/2009/page_255.pdf-3
# Added document with ID: Double_AON/2013/page_54.pdf
# Added document with ID: Single_CAT/2017/page_136.pdf-1
# Added document with ID: Single_AON/2011/page_61.pdf-1
# Added document with ID: Single_AAPL/2012/page_64.pdf-1
# Added document with ID: Single_CB/2008/page_243.pdf-3
# Added document with ID: Single_IP/2012/page_57.pdf-1
# Added document with ID: Single_LMT/2017/page_101.pdf-2
# Added document with ID: Single_GS/2018/page_68.pdf-1
# Added document with ID: Double_GRMN/2008/page_98.pdf
# Added document with ID: Single_SNPS/2006/page_67.pdf-1
# Added document with ID: Single_MRO/2008/page_130.pdf-3
# Added document with ID: Single_ETR/2013/page_15.pdf-2
# Added document with ID: Single_ETR/2008/page_266.pdf-1
# Added document with ID: Single_ECL/2017/page_95.pdf-4
# Added document with ID: Single_AMT/2010/page_111.pdf-4
# Added document with ID: Single_UNP/2011/page_80.pdf-2
# Added document with ID: Single_UNP/2009/page_31.pdf-1
# Added document with ID: Single_ADI/2019/page_77.pdf-2
# Added document with ID: Double_HIG/2016/page_253.pdf
# Added document with ID: Single_SNPS/2006/page_43.pdf-1
# Added document with ID: Single_AWK/2015/page_117.pdf-3
# Added document with ID: Double_PPG/2018/page_61.pdf
# Added document with ID: Single_EMR/2018/page_28.pdf-2
# Added document with ID: Single_RCL/2005/page_40.pdf-2
# Added document with ID: Single_WMT/2018/page_46.pdf-2
# Added document with ID: Single_ETR/2008/page_267.pdf-1
# Added document with ID: Double_ETR/2015/page_24.pdf
# Added document with ID: Single_ZBH/2007/page_80.pdf-1
# Added document with ID: Single_AMAT/2012/page_37.pdf-2
# Added document with ID: Single_PNC/2013/page_232.pdf-1
# Added document with ID: Double_UNP/2014/page_31.pdf
# Added document with ID: Single_UNP/2006/page_45.pdf-3
# Added document with ID: Single_BLL/2010/page_33.pdf-3
# Added document with ID: Single_ETR/2002/page_38.pdf-2
# Added document with ID: Double_MRO/2008/page_119.pdf
# Added document with ID: Single_DVN/2012/page_100.pdf-1
# Added document with ID: Double_GS/2017/page_74.pdf
# Added document with ID: Double_CME/2012/page_73.pdf
# Added document with ID: Double_PPG/2010/page_45.pdf
# Added document with ID: Double_JKHY/2016/page_25.pdf
# Added document with ID: Single_PPG/2013/page_54.pdf-2
# Added document with ID: Double_MMM/2007/page_38.pdf
# Added document with ID: Single_IP/2007/page_32.pdf-3
# Added document with ID: Single_CAT/2017/page_103.pdf-3
# Added document with ID: Double_STT/2014/page_69.pdf
# Added document with ID: Single_MRO/2012/page_39.pdf-2
# Added document with ID: Double_ETR/2004/page_19.pdf
# Added document with ID: Double_UNP/2014/page_21.pdf
# Added document with ID: Single_LMT/2014/page_46.pdf-3
# Added document with ID: Single_BLK/2016/page_79.pdf-1
# Added document with ID: Single_GIS/2018/page_77.pdf-1
# Added document with ID: Single_UNP/2009/page_38.pdf-4
# Added document with ID: Single_CB/2008/page_218.pdf-1
# Added document with ID: Single_ANSS/2016/page_82.pdf-1
# Added document with ID: Single_UNP/2012/page_74.pdf-2
# Added document with ID: Single_AMAT/2014/page_37.pdf-2
# Added document with ID: Single_CME/2010/page_113.pdf-5
# Added document with ID: Single_HUM/2007/page_96.pdf-2
# Added document with ID: Single_ORLY/2009/page_77.pdf-1
# Added document with ID: Double_NWS/2019/page_120.pdf
# Added document with ID: Single_IPG/2014/page_95.pdf-2
# Added document with ID: Single_GPN/2018/page_74.pdf-2
# Added document with ID: Single_REGN/2010/page_64.pdf-3
# Added document with ID: Single_ETR/2004/page_261.pdf-4
# Added document with ID: Double_LMT/2012/page_43.pdf
# Added document with ID: Single_STT/2013/page_54.pdf-2
# Added document with ID: Double_RCL/2014/page_16.pdf
# Added document with ID: Single_AES/2001/page_78.pdf-2
# Added document with ID: Single_CMCSA/2015/page_150.pdf-2
# Added document with ID: Double_MRO/2012/page_41.pdf
# Added document with ID: Single_MRO/2013/page_49.pdf-2
# Added document with ID: Double_ZBH/2008/page_83.pdf
# Added document with ID: Single_LKQ/2007/page_76.pdf-1
# Added document with ID: Single_AMAT/2014/page_37.pdf-4
# Added document with ID: Single_MA/2009/page_112.pdf-1
# Added document with ID: Single_UA/2015/page_77.pdf-2
# Added document with ID: Single_C/2008/page_173.pdf-1
# Added document with ID: Double_RL/2008/page_21.pdf
# Added document with ID: Single_SLB/2009/page_46.pdf-3
# Added document with ID: Single_ETR/2015/page_24.pdf-1
# Added document with ID: Single_AAP/2013/page_32.pdf-1
# Added document with ID: Single_AMT/2015/page_50.pdf-1
# Added document with ID: Single_UNP/2013/page_73.pdf-2
# Added document with ID: Single_CB/2008/page_216.pdf-1
# Added document with ID: Single_ETR/2017/page_352.pdf-3
# Added document with ID: Single_ILMN/2007/page_84.pdf-1
# Added document with ID: Double_HWM/2016/page_53.pdf
# Added document with ID: Single_SLG/2011/page_58.pdf-1
# Added document with ID: Double_AMAT/2012/page_37.pdf
# Added document with ID: Double_IPG/2015/page_79.pdf
# Added document with ID: Single_IPG/2016/page_46.pdf-1
# Added document with ID: Double_HII/2013/page_116.pdf
# Added document with ID: Single_LMT/2012/page_72.pdf-1
# Added document with ID: Single_CDW/2013/page_106.pdf-3
# Added document with ID: Single_MO/2017/page_10.pdf-3
# Added document with ID: Single_RE/2013/page_109.pdf-3
# Added document with ID: Single_APD/2014/page_71.pdf-1
# Added document with ID: Double_STT/2008/page_109.pdf
# Added document with ID: Single_ETFC/2007/page_22.pdf-2
# Added document with ID: Double_AAPL/2004/page_83.pdf
# Added document with ID: Single_AAPL/2007/page_51.pdf-1
# Added document with ID: Double_JPM/2016/page_87.pdf
# Added document with ID: Single_ZBH/2013/page_49.pdf-1
# Added document with ID: Single_UNP/2006/page_72.pdf-2
# Added document with ID: Single_MS/2013/page_240.pdf-4
# Added document with ID: Double_ETR/2017/page_379.pdf
# Added document with ID: Double_BLK/2017/page_81.pdf
# Added document with ID: Single_AES/2003/page_55.pdf-2
# Added document with ID: Single_SLB/2009/page_46.pdf-4
# Added document with ID: Single_AWK/2018/page_142.pdf-3
# Added document with ID: Double_LMT/2018/page_86.pdf
# Added document with ID: Single_DVN/2011/page_99.pdf-1
# Added document with ID: Single_IPG/2013/page_36.pdf-4
# Added document with ID: Single_STT/2013/page_54.pdf-1
# Added document with ID: Single_TFX/2018/page_47.pdf-1
# Added document with ID: Single_HOLX/2008/page_128.pdf-2
# Added document with ID: Single_AON/2015/page_62.pdf-4
# Added document with ID: Double_CB/2009/page_220.pdf
# Added document with ID: Double_TFX/2018/page_47.pdf
# Added document with ID: Single_BLK/2012/page_32.pdf-3
# Added document with ID: Single_GS/2012/page_56.pdf-3
# Added document with ID: Single_AES/2018/page_168.pdf-3
# Added document with ID: Double_RL/2016/page_9.pdf
# Added document with ID: Single_APD/2013/page_44.pdf-2
# Added document with ID: Double_C/2008/page_176.pdf
# Added document with ID: Single_IP/2014/page_65.pdf-1
# Added document with ID: Single_DISCA/2016/page_30.pdf-4
# Added document with ID: Single_RSG/2008/page_56.pdf-1
# Added document with ID: Single_ETR/2004/page_261.pdf-1
# Added document with ID: Single_ETR/2017/page_25.pdf-3
# Added document with ID: Single_AON/2010/page_52.pdf-1
# Added document with ID: Single_HUM/2004/page_78.pdf-2
# Added document with ID: Single_ADI/2011/page_92.pdf-2
# Added document with ID: Single_AOS/2016/page_19.pdf-2
# Added document with ID: Single_UA/2011/page_66.pdf-1
# Added document with ID: Single_LMT/2010/page_36.pdf-2
# Added document with ID: Double_LMT/2017/page_83.pdf
# Added document with ID: Single_PNC/2011/page_74.pdf-2
# Added document with ID: Double_GS/2012/page_56.pdf
# Added document with ID: Single_RE/2006/page_31.pdf-1
# Added document with ID: Double_AAL/2014/page_80.pdf
# Added document with ID: Double_ADBE/2014/page_47.pdf
# Added document with ID: Single_AWK/2018/page_141.pdf-2
# Added document with ID: Single_UA/2015/page_42.pdf-2
# Added document with ID: Single_MO/2014/page_11.pdf-4
# Added document with ID: Single_UNP/2013/page_73.pdf-4
# Added document with ID: Double_DISCA/2016/page_30.pdf
# Added document with ID: Single_ABMD/2003/page_27.pdf-4
# Added document with ID: Single_UNP/2016/page_75.pdf-4
# Added document with ID: Single_GS/2018/page_76.pdf-4
# Added document with ID: Double_PPG/2010/page_68.pdf
# Added document with ID: Double_GS/2014/page_80.pdf
# Added document with ID: Double_MSI/2007/page_42.pdf
# Added document with ID: Single_DRE/2009/page_60.pdf-2
# Added document with ID: Single_VTR/2007/page_48.pdf-1
# Added document with ID: Single_BKNG/2017/page_35.pdf-1
# Added document with ID: Single_BLK/2017/page_87.pdf-4
# Added document with ID: Single_DISCA/2016/page_11.pdf-2
# Added document with ID: Double_UNP/2012/page_40.pdf
# Added document with ID: Single_FIS/2006/page_98.pdf-1
# Added document with ID: Double_ANSS/2008/page_89.pdf
# Added document with ID: Single_AMT/2007/page_35.pdf-4
# Added document with ID: Single_PNC/2012/page_58.pdf-3
# Added document with ID: Double_SNPS/2012/page_61.pdf
# Added document with ID: Double_CME/2012/page_100.pdf
# Added document with ID: Double_AMT/2005/page_56.pdf
# Added document with ID: Single_FITB/2013/page_84.pdf-4
# Added document with ID: Double_VRTX/2006/page_71.pdf
# Added document with ID: Single_UNP/2016/page_24.pdf-1
# Added document with ID: Single_HII/2011/page_60.pdf-2
# Added document with ID: Single_UNP/2012/page_47.pdf-2
# Added document with ID: Single_AON/2011/page_38.pdf-1
# Added document with ID: Single_STT/2001/page_41.pdf-3
# Added document with ID: Single_KMI/2014/page_114.pdf-2
# Added document with ID: Single_ABMD/2006/page_62.pdf-2
# Added document with ID: Single_AAP/2006/page_85.pdf-4
# Added document with ID: Single_LMT/2007/page_55.pdf-3
# Added document with ID: Double_LKQ/2007/page_76.pdf
# Added document with ID: Single_CE/2014/page_32.pdf-3
# Added document with ID: Double_RL/2014/page_13.pdf
# Added document with ID: Single_DRE/2012/page_34.pdf-3
# Added document with ID: Double_CDW/2015/page_54.pdf
# Added document with ID: Single_AWK/2018/page_148.pdf-1
# Added document with ID: Double_JPM/2003/page_44.pdf
# Added document with ID: Single_BLK/2017/page_87.pdf-3
# Added document with ID: Single_IP/2007/page_30.pdf-4
# Added document with ID: Single_WRK/2019/page_135.pdf-1
# Added document with ID: Single_AMAT/2015/page_14.pdf-2
# Added document with ID: Single_GS/2012/page_50.pdf-1
# Added document with ID: Double_AON/2010/page_52.pdf
# Added document with ID: Single_BLL/2007/page_75.pdf-3
# Added document with ID: Single_ADI/2016/page_61.pdf-1
# Added document with ID: Single_AMT/2010/page_82.pdf-1
# Added document with ID: Double_RE/2010/page_42.pdf
# Added document with ID: Single_ETFC/2007/page_22.pdf-1
# Added document with ID: Single_UPS/2015/page_108.pdf-3
# Added document with ID: Single_LMT/2012/page_81.pdf-4
# Added document with ID: Single_RE/2012/page_31.pdf-4
# Added document with ID: Single_DVN/2013/page_101.pdf-3
# Added document with ID: Double_STT/2017/page_101.pdf
# Added document with ID: Double_STT/2009/page_122.pdf
# Added document with ID: Single_JPM/2015/page_77.pdf-5
# Added document with ID: Single_AOS/2007/page_17.pdf-2
# Added document with ID: Single_RCL/2014/page_16.pdf-4
# Added document with ID: Double_RE/2015/page_131.pdf
# Added document with ID: Single_ETR/2004/page_216.pdf-4
# Added document with ID: Single_AWK/2012/page_12.pdf-1
# Added document with ID: Double_FIS/2010/page_93.pdf
# Added document with ID: Single_AON/2010/page_55.pdf-3
# Added document with ID: Single_ADI/2007/page_82.pdf-2
# Added document with ID: Single_STT/2008/page_116.pdf-2
# Added document with ID: Single_GPN/2008/page_92.pdf-2
# Added document with ID: Double_GIS/2006/page_43.pdf
# Added document with ID: Single_PNC/2012/page_222.pdf-3
# Added document with ID: Double_GPN/2016/page_83.pdf
# Added document with ID: Single_PNC/2007/page_108.pdf-1
# Added document with ID: Double_IPG/2016/page_86.pdf
# Added document with ID: Double_STT/2011/page_94.pdf
# Added document with ID: Single_MO/2017/page_65.pdf-4
# Added document with ID: Double_LMT/2014/page_93.pdf
# Added document with ID: Single_D/2002/page_39.pdf-1
# Added document with ID: Double_CE/2007/page_125.pdf
# Added document with ID: Single_LLY/2008/page_43.pdf-1
# Added document with ID: Single_AWK/2015/page_109.pdf-2
# Added document with ID: Double_AON/2015/page_43.pdf
# Added document with ID: Single_ETR/2008/page_130.pdf-4
# Added document with ID: Single_ETR/2017/page_325.pdf-1
# Added document with ID: Single_UPS/2012/page_51.pdf-2
# Added document with ID: Double_PNC/2015/page_48.pdf
# Added document with ID: Single_ADBE/2003/page_111.pdf-2
# Added document with ID: Single_C/2009/page_48.pdf-2
# Added document with ID: Single_PPG/2018/page_60.pdf-2
# Added document with ID: Single_LMT/2016/page_85.pdf-1
# Added document with ID: Single_MRO/2012/page_39.pdf-3
# Added document with ID: Single_RCL/2016/page_37.pdf-3
# Added document with ID: Single_BLK/2016/page_35.pdf-1
# Added document with ID: Single_UPS/2014/page_35.pdf-3
# Added document with ID: Single_MRO/2014/page_55.pdf-3
# Added document with ID: Single_FIS/2007/page_33.pdf-2
# Added document with ID: Double_PNC/2014/page_232.pdf
# Added document with ID: Double_ADI/2010/page_73.pdf
# Added document with ID: Double_LMT/2018/page_29.pdf
# Added document with ID: Single_ZBH/2017/page_50.pdf-2
# Added document with ID: Double_LLY/2008/page_39.pdf
# Added document with ID: Single_CDW/2015/page_53.pdf-1
# Added document with ID: Single_PPG/2011/page_28.pdf-3
# Added document with ID: Single_KIM/2009/page_25.pdf-1
# Added document with ID: Double_AWK/2018/page_150.pdf
# Added document with ID: Single_MA/2009/page_120.pdf-1
# Added document with ID: Single_LMT/2016/page_83.pdf-2
# Added document with ID: Single_BKR/2018/page_59.pdf-3
# Added document with ID: Single_AON/2011/page_61.pdf-3
# Added document with ID: Single_HII/2018/page_124.pdf-4
# Added document with ID: Single_UAA/2018/page_40.pdf-4
# Added document with ID: Single_FIS/2017/page_14.pdf-1
# Added document with ID: Double_AES/2001/page_45.pdf
# Added document with ID: Single_MA/2018/page_34.pdf-1
# Added document with ID: Single_MSI/2008/page_110.pdf-3
# Added document with ID: Single_BKNG/2018/page_34.pdf-1
# Added document with ID: Single_AMT/2002/page_74.pdf-4
# Added document with ID: Single_UNP/2015/page_76.pdf-2
# Added document with ID: Double_ETR/2008/page_313.pdf
# Added document with ID: Double_GS/2013/page_97.pdf
# Added document with ID: Double_JPM/2013/page_158.pdf
# Added document with ID: Single_EL/2013/page_117.pdf-2
# Added document with ID: Double_JPM/2017/page_83.pdf
# Added document with ID: Single_SLB/2010/page_90.pdf-2
# Added document with ID: Single_STT/2008/page_112.pdf-3
# Added document with ID: Double_JPM/2010/page_132.pdf
# Added document with ID: Single_KHC/2017/page_21.pdf-3
# Added document with ID: Double_MRO/2008/page_135.pdf
# Added document with ID: Single_IP/2018/page_83.pdf-1
# Added document with ID: Double_GPN/2017/page_88.pdf
# Added document with ID: Single_PPG/2012/page_76.pdf-4
# Added document with ID: Double_JPM/2012/page_109.pdf
# Added document with ID: Single_IP/2012/page_55.pdf-3
# Added document with ID: Single_IP/2015/page_44.pdf-2
# Added document with ID: Single_HII/2011/page_114.pdf-3
# Added document with ID: Double_KIM/2010/page_103.pdf
# Added document with ID: Double_HIG/2011/page_195.pdf
# Added document with ID: Double_AON/2009/page_70.pdf
# Added document with ID: Single_MRO/2012/page_41.pdf-1
# Added document with ID: Double_RSG/2010/page_157.pdf
# Added document with ID: Single_AMT/2005/page_31.pdf-1
# Added document with ID: Double_AON/2015/page_72.pdf
# Added document with ID: Double_CMCSA/2015/page_62.pdf
# Added document with ID: Double_ZBH/2007/page_54.pdf
# Added document with ID: Single_SNA/2007/page_47.pdf-1
# Added document with ID: Single_MSI/2008/page_73.pdf-2
# Added document with ID: Single_LMT/2012/page_46.pdf-1
# Added document with ID: Double_AWK/2012/page_118.pdf
# Added document with ID: Double_TSCO/2017/page_68.pdf
# Added document with ID: Double_ANET/2017/page_156.pdf
# Added document with ID: Single_UNP/2012/page_74.pdf-1
# Added document with ID: Single_ADBE/2013/page_84.pdf-1
# Added document with ID: Single_KIM/2010/page_86.pdf-3
# Added document with ID: Single_ADBE/2013/page_84.pdf-3
# Added document with ID: Double_C/2009/page_248.pdf
# Added document with ID: Single_CME/2017/page_83.pdf-1
# Added document with ID: Single_MRO/2008/page_70.pdf-1
# Added document with ID: Double_UAA/2016/page_83.pdf
# Added document with ID: Single_IP/2012/page_58.pdf-2
# Added document with ID: Single_JPM/2017/page_83.pdf-2
# Added document with ID: Single_CME/2010/page_109.pdf-3
# Added document with ID: Single_AES/2002/page_60.pdf-3
# Added document with ID: Single_APTV/2016/page_47.pdf-1
# Added document with ID: Single_HII/2011/page_69.pdf-1
# Added document with ID: Single_AAPL/2007/page_84.pdf-3
# Added document with ID: Double_MRO/2009/page_32.pdf
# Added document with ID: Single_IPG/2017/page_26.pdf-1
# Added document with ID: Double_RSG/2008/page_114.pdf
# Added document with ID: Single_FIS/2006/page_48.pdf-4
# Added document with ID: Single_HOLX/2011/page_122.pdf-3
# Added document with ID: Single_AMT/2005/page_84.pdf-4
# Added document with ID: Single_UNP/2006/page_36.pdf-3
# Added document with ID: Single_AAPL/2012/page_38.pdf-4
# Added document with ID: Single_IPG/2017/page_38.pdf-2
# Added document with ID: Single_ZBH/2013/page_46.pdf-1
# Added document with ID: Single_IPG/2007/page_97.pdf-3
# Added document with ID: Single_RE/2016/page_40.pdf-4
# Added document with ID: Double_WELL/2017/page_116.pdf
# Added document with ID: Single_HUM/2005/page_80.pdf-4
# Added document with ID: Single_DVN/2012/page_100.pdf-2
# Added document with ID: Single_MRK/2013/page_116.pdf-2
# Added document with ID: Single_UAA/2016/page_82.pdf-3
# Added document with ID: Single_LMT/2012/page_45.pdf-1
# Added document with ID: Single_ETR/2008/page_376.pdf-2
# Added document with ID: Single_ECL/2015/page_70.pdf-2
# Added document with ID: Single_ETR/2017/page_20.pdf-1
# Added document with ID: Double_JPM/2013/page_104.pdf
# Added document with ID: Single_PNC/2008/page_144.pdf-1
# Added document with ID: Single_UNP/2006/page_55.pdf-4
# Added document with ID: Single_FIS/2006/page_88.pdf-4
# Added document with ID: Single_ZBH/2015/page_35.pdf-2
# Added document with ID: Single_ANET/2015/page_155.pdf-3
# Added document with ID: Single_RE/2014/page_40.pdf-4
# Added document with ID: Single_IP/2013/page_62.pdf-1
# Added document with ID: Double_RCL/2012/page_80.pdf
# Added document with ID: Single_WRK/2019/page_103.pdf-3
# Added document with ID: Single_DVN/2010/page_70.pdf-2
# Added document with ID: Single_FIS/2006/page_48.pdf-2
# Added document with ID: Double_MKTX/2004/page_24.pdf
# Added document with ID: Double_HFC/2011/page_88.pdf
# Added document with ID: Single_LMT/2016/page_83.pdf-4
# Added document with ID: Single_IPG/2014/page_36.pdf-1
# Added document with ID: Double_UAA/2016/page_82.pdf
# Added document with ID: Single_UNP/2017/page_74.pdf-4
# Added document with ID: Double_HWM/2015/page_95.pdf
# Added document with ID: Single_VLO/2013/page_24.pdf-1
# Added document with ID: Single_UPS/2009/page_33.pdf-1
# Added document with ID: Single_ETR/2016/page_375.pdf-1
# Added document with ID: Single_UAA/2016/page_82.pdf-1
# Added document with ID: Single_PPG/2018/page_32.pdf-1
# Added document with ID: Single_AON/2009/page_70.pdf-1
# Added document with ID: Double_AAP/2016/page_96.pdf
# Added document with ID: Double_ETR/2008/page_441.pdf
# Added document with ID: Single_DVN/2011/page_99.pdf-2
# Added document with ID: Single_RSG/2008/page_43.pdf-1
# Added document with ID: Single_GS/2018/page_212.pdf-1
# Added document with ID: Double_C/2018/page_200.pdf
# Added document with ID: Single_AMT/2015/page_58.pdf-1
# Added document with ID: Double_AAPL/2011/page_24.pdf
# Added document with ID: Double_GPN/2008/page_88.pdf
# Added document with ID: Single_BKR/2017/page_47.pdf-4
# Added document with ID: Single_UNP/2007/page_58.pdf-1
# Added document with ID: Double_CE/2016/page_88.pdf
# Added document with ID: Single_PPG/2012/page_47.pdf-4
# Added document with ID: Single_GPN/2008/page_39.pdf-2
# Added document with ID: Double_ETR/2008/page_266.pdf
# Added document with ID: Double_HOLX/2008/page_140.pdf
# Added document with ID: Single_V/2013/page_116.pdf-3
# Added document with ID: Single_MRO/2012/page_40.pdf-2
# Added document with ID: Double_IP/2005/page_27.pdf
# Added document with ID: Single_SLB/2003/page_57.pdf-2
# Added document with ID: Single_AAPL/2012/page_71.pdf-2
# Added document with ID: Single_PPG/2016/page_42.pdf-3
# Added document with ID: Single_HUM/2007/page_96.pdf-4
# Added document with ID: Single_GIS/2018/page_59.pdf-2
# Added document with ID: Single_JPM/2010/page_236.pdf-2
# Added document with ID: Single_EW/2013/page_83.pdf-1
# Added document with ID: Double_PM/2015/page_32.pdf
# Added document with ID: Single_ADI/2009/page_90.pdf-1
# Added document with ID: Double_RCL/2011/page_16.pdf
# Added document with ID: Single_ETR/2011/page_377.pdf-3
# Added document with ID: Single_ILMN/2007/page_84.pdf-2
# Added document with ID: Single_VTR/2007/page_48.pdf-3
# Added document with ID: Single_CDW/2015/page_35.pdf-2
# Added document with ID: Double_WRK/2019/page_51.pdf
# Added document with ID: Single_ETR/2013/page_28.pdf-1
# Added document with ID: Single_DG/2006/page_58.pdf-1
# Added document with ID: Double_CE/2006/page_124.pdf
# Added document with ID: Single_ZBH/2018/page_34.pdf-2
# Added document with ID: Single_AMT/2008/page_105.pdf-2
# Added document with ID: Double_ETR/2007/page_36.pdf
# Added document with ID: Double_ETR/2008/page_154.pdf
# Added document with ID: Single_EXPD/2017/page_30.pdf-2
# Added document with ID: Single_LMT/2012/page_45.pdf-2
# Added document with ID: Single_PM/2015/page_32.pdf-2
# Added document with ID: Single_MRK/2013/page_116.pdf-1
# Added document with ID: Single_CE/2011/page_17.pdf-4
# Added document with ID: Double_GS/2014/page_62.pdf
# Added document with ID: Single_PM/2017/page_25.pdf-4
# Added document with ID: Single_GIS/2006/page_51.pdf-1
# Added document with ID: Single_PPG/2006/page_21.pdf-4
# Added document with ID: Single_IP/2018/page_50.pdf-2
# Added document with ID: Single_AES/2003/page_55.pdf-3
# Added document with ID: Single_ETR/2008/page_401.pdf-2
# Added document with ID: Double_PNC/2007/page_93.pdf
# Added document with ID: Single_IPG/2018/page_104.pdf-1
# Added document with ID: Single_RCL/2006/page_37.pdf-3
# Added document with ID: Double_AAPL/2012/page_24.pdf
# Added document with ID: Single_TFX/2014/page_74.pdf-1
# Added document with ID: Single_CE/2007/page_125.pdf-1
# Added document with ID: Single_RSG/2010/page_132.pdf-1
# Added document with ID: Single_AAPL/2015/page_68.pdf-4
# Added document with ID: Single_BLL/2010/page_58.pdf-4
# Added document with ID: Double_SNPS/2006/page_46.pdf
# Added document with ID: Single_RE/2015/page_131.pdf-1
# Added document with ID: Single_PPG/2011/page_28.pdf-4
# Added document with ID: Single_JPM/2007/page_119.pdf-3
# Added document with ID: Single_AAPL/2015/page_24.pdf-3
# Added document with ID: Single_RSG/2010/page_135.pdf-2
# Added document with ID: Double_EMR/2017/page_54.pdf
# Added document with ID: Double_AAPL/2015/page_56.pdf
# Added document with ID: Double_AMT/2003/page_92.pdf
# Added document with ID: Single_UNP/2011/page_80.pdf-1
# Added document with ID: Double_ECL/2017/page_96.pdf
# Added document with ID: Single_LMT/2014/page_46.pdf-2
# Added document with ID: Single_BLK/2017/page_81.pdf-3
# Added document with ID: Double_AAP/2006/page_85.pdf
# Added document with ID: Single_AAPL/2016/page_23.pdf-4
# Added document with ID: Single_CB/2008/page_216.pdf-2
# Added document with ID: Single_AAP/2012/page_61.pdf-4
# Added document with ID: Single_FITB/2008/page_69.pdf-4
# Added document with ID: Single_UPS/2009/page_33.pdf-4
# Added document with ID: Single_RCL/2018/page_38.pdf-1
# Added document with ID: Single_AMT/2010/page_115.pdf-2
# Added document with ID: Double_WRK/2019/page_135.pdf
# Added document with ID: Single_UNP/2009/page_25.pdf-2
# Added document with ID: Double_IQV/2018/page_59.pdf
# Added document with ID: Single_UNP/2006/page_62.pdf-1
# Added document with ID: Single_DVN/2013/page_101.pdf-2
# Added document with ID: Single_C/2017/page_205.pdf-3
# Added document with ID: Single_AAL/2017/page_10.pdf-3
# Added document with ID: Single_RSG/2014/page_123.pdf-1
# Added document with ID: Double_AAL/2014/page_59.pdf
# Added document with ID: Double_PNC/2014/page_203.pdf
# Added document with ID: Single_LMT/2013/page_45.pdf-2
# Added document with ID: Double_APTV/2015/page_47.pdf
# Added document with ID: Single_IP/2015/page_44.pdf-4
# Added document with ID: Single_UNP/2013/page_25.pdf-3
# Added document with ID: Single_EMN/2006/page_110.pdf-2
# Added document with ID: Single_MSI/2008/page_110.pdf-2
# Added document with ID: Single_MMM/2007/page_16.pdf-1
# Added document with ID: Single_CME/2010/page_71.pdf-3
# Added document with ID: Single_RCL/2012/page_17.pdf-2
# Added document with ID: Single_FBHS/2017/page_46.pdf-1
# Added document with ID: Single_VNO/2010/page_173.pdf-1
# Added document with ID: Single_PM/2014/page_112.pdf-4
# Added document with ID: Double_GS/2017/page_104.pdf
# Added document with ID: Double_UPS/2015/page_35.pdf
# Added document with ID: Single_IP/2005/page_27.pdf-1
# Added document with ID: Double_RSG/2008/page_141.pdf
# Added document with ID: Single_GPN/2010/page_92.pdf-1
# Added document with ID: Single_GPN/2015/page_82.pdf-2
# Added document with ID: Single_AMT/2002/page_74.pdf-3
# Added document with ID: Single_ABMD/2018/page_112.pdf-4
# Added document with ID: Single_IP/2014/page_101.pdf-4
# Added document with ID: Single_MAS/2012/page_86.pdf-2
# Added document with ID: Double_MAR/2005/page_52.pdf
# Added document with ID: Single_BDX/2009/page_80.pdf-2
# Added document with ID: Double_MAR/2018/page_42.pdf
# Added document with ID: Double_AMT/2005/page_77.pdf
# Added document with ID: Double_SLG/2013/page_133.pdf
# Added document with ID: Single_AAP/2013/page_68.pdf-3
# Added document with ID: Double_INTC/2016/page_100.pdf
# Added document with ID: Single_MAS/2017/page_37.pdf-2
# Added document with ID: Single_RCL/2014/page_80.pdf-3
# Added document with ID: Single_HII/2012/page_127.pdf-3
# Added document with ID: Single_ETR/2004/page_185.pdf-1
# Added document with ID: Single_GS/2012/page_196.pdf-1
# Added document with ID: Single_SNPS/2003/page_39.pdf-1
# Added document with ID: Double_UA/2011/page_70.pdf
# Added document with ID: Single_BLK/2014/page_33.pdf-2
# Added document with ID: Single_FIS/2016/page_64.pdf-2
# Added document with ID: Double_BLL/2007/page_87.pdf
# Added document with ID: Single_STT/2014/page_99.pdf-1
# Added document with ID: Single_ZBH/2008/page_83.pdf-3
# Added document with ID: Double_HUM/2007/page_96.pdf
# Added document with ID: Double_AWK/2015/page_81.pdf
# Added document with ID: Single_RCL/2016/page_7.pdf-2
# Added document with ID: Single_TSCO/2017/page_73.pdf-2
# Added document with ID: Single_K/2012/page_80.pdf-1
# Added document with ID: Single_AWK/2017/page_154.pdf-2
# Added document with ID: Single_PM/2017/page_25.pdf-2
# Added document with ID: Single_ETR/2017/page_379.pdf-3
# Added document with ID: Double_ADI/2009/page_59.pdf
# Added document with ID: Single_AAP/2016/page_26.pdf-1
# Added document with ID: Single_ZBH/2013/page_49.pdf-2
# Added document with ID: Single_ETR/2016/page_343.pdf-4
# Added document with ID: Single_UNP/2010/page_55.pdf-1
# Added document with ID: Single_C/2008/page_105.pdf-1
# Added document with ID: Single_PNC/2009/page_31.pdf-6
# Added document with ID: Single_MRO/2007/page_79.pdf-2
# Added document with ID: Double_IP/2015/page_46.pdf
# Added document with ID: Single_FITB/2008/page_69.pdf-1
# Added document with ID: Single_SNPS/2006/page_68.pdf-2
# Added document with ID: Double_HIG/2004/page_81.pdf
# Added document with ID: Single_AMT/2010/page_41.pdf-2
# Added document with ID: Single_VRTX/2006/page_112.pdf-1
# Added document with ID: Single_BDX/2009/page_80.pdf-4
# Added document with ID: Single_GPN/2009/page_85.pdf-3
# Added document with ID: Single_STT/2017/page_101.pdf-3
# Added document with ID: Single_AAP/2016/page_65.pdf-3
# Added document with ID: Single_UNP/2010/page_30.pdf-3
# Added document with ID: Single_RCL/2016/page_37.pdf-2
# Added document with ID: Double_AES/2010/page_225.pdf
# Added document with ID: Single_MMM/2007/page_68.pdf-1
# Added document with ID: Double_GS/2012/page_57.pdf
# Added document with ID: Double_GPN/2016/page_67.pdf
# Added document with ID: Single_INTC/2018/page_48.pdf-3
# Added document with ID: Single_HIG/2004/page_192.pdf-2
# Added document with ID: Single_VNO/2011/page_177.pdf-1
# Added document with ID: Single_AAP/2016/page_96.pdf-3
# Added document with ID: Double_HOLX/2004/page_87.pdf
# Added document with ID: Single_CDNS/2007/page_93.pdf-3
# Added document with ID: Single_BLL/2006/page_89.pdf-3
# Added document with ID: Single_HFC/2011/page_88.pdf-4
# Added document with ID: Single_RE/2006/page_39.pdf-2
# Added document with ID: Double_ADI/2016/page_61.pdf
# Added document with ID: Single_AAP/2012/page_61.pdf-3
# Added document with ID: Single_UNP/2009/page_26.pdf-1
# Added document with ID: Single_JPM/2010/page_219.pdf-4
# Added document with ID: Single_ADBE/2011/page_83.pdf-3
# Added document with ID: Double_ADBE/2011/page_112.pdf
# Added document with ID: Double_AES/2002/page_117.pdf
# Added document with ID: Single_STT/2007/page_65.pdf-1
# Added document with ID: Double_GIS/2018/page_59.pdf
# Added document with ID: Double_INTC/2016/page_33.pdf
# Added document with ID: Single_CAT/2017/page_103.pdf-4
# Added document with ID: Single_JPM/2009/page_132.pdf-2
# Added document with ID: Single_BDX/2019/page_86.pdf-3
# Added document with ID: Double_AES/2003/page_93.pdf
# Added document with ID: Single_LMT/2018/page_85.pdf-1
# Added document with ID: Double_C/2010/page_229.pdf
# Added document with ID: Single_UNP/2016/page_75.pdf-3
# Added document with ID: Double_RL/2012/page_13.pdf
# Added document with ID: Single_DVN/2014/page_112.pdf-4
# Added document with ID: Single_MRO/2006/page_61.pdf-1
# Added document with ID: Single_FITB/2013/page_84.pdf-1
# Added document with ID: Single_UNP/2009/page_43.pdf-2
# Added document with ID: Double_AMT/2002/page_74.pdf
# Added document with ID: Single_BLK/2017/page_77.pdf-2
# Added document with ID: Single_IPG/2014/page_36.pdf-4
# Added document with ID: Single_UNP/2014/page_24.pdf-2
# Added document with ID: Single_VLO/2016/page_23.pdf-3
# Added document with ID: Single_SLG/2013/page_133.pdf-2
# Added document with ID: Double_AWK/2017/page_140.pdf
# Added document with ID: Single_ZBH/2004/page_68.pdf-1
# Added document with ID: Single_AMT/2004/page_102.pdf-1
# Added document with ID: Single_JPM/2010/page_236.pdf-1
# Added document with ID: Single_UPS/2012/page_51.pdf-4
# Added document with ID: Single_AAPL/2006/page_93.pdf-1
# Added document with ID: Single_JPM/2014/page_127.pdf-3
# Added document with ID: Double_MRO/2012/page_39.pdf
# Added document with ID: Double_STT/2013/page_71.pdf
# Added document with ID: Single_BLL/2007/page_75.pdf-2
# Added document with ID: Single_KIM/2008/page_126.pdf-3
# Added document with ID: Single_UPS/2007/page_32.pdf-2
# Added document with ID: Double_L/2009/page_52.pdf
# Added document with ID: Double_DISH/2011/page_130.pdf
# Added document with ID: Single_GS/2012/page_50.pdf-2
# Added document with ID: Single_HIG/2011/page_195.pdf-1
# Added document with ID: Single_HOLX/2007/page_133.pdf-2
# Added document with ID: Double_HII/2018/page_113.pdf
# Added document with ID: Single_SNPS/2006/page_73.pdf-1
# Added document with ID: Single_ETR/2016/page_267.pdf-2
# Added document with ID: Double_ETFC/2013/page_84.pdf
# Added document with ID: Single_AMT/2015/page_58.pdf-3
# Added document with ID: Single_HOLX/2009/page_153.pdf-4
# Added document with ID: Single_BLK/2017/page_87.pdf-2
# Added document with ID: Single_UPS/2017/page_111.pdf-3
# Added document with ID: Single_CME/2017/page_99.pdf-6
# Added document with ID: Single_ETR/2017/page_19.pdf-1
# Added document with ID: Double_ETR/2017/page_19.pdf
# Added document with ID: Single_ETR/2016/page_144.pdf-4
# Added document with ID: Single_ETR/2008/page_314.pdf-4
# Added document with ID: Single_GPN/2007/page_39.pdf-1
# Added document with ID: Single_SNA/2013/page_111.pdf-2
# Added document with ID: Double_AWK/2015/page_117.pdf
# Added document with ID: Double_TROW/2008/page_23.pdf
# Added document with ID: Single_ETR/2011/page_273.pdf-4
# Added document with ID: Single_AES/2002/page_117.pdf-1
# Added document with ID: Double_VRTX/2005/page_112.pdf
# Added document with ID: Single_AMT/2005/page_84.pdf-2
# Added document with ID: Single_IPG/2009/page_89.pdf-3
# Added document with ID: Double_DRE/2009/page_60.pdf
# Added document with ID: Single_CB/2009/page_220.pdf-2
# Added document with ID: Double_UNP/2014/page_56.pdf
# Added document with ID: Double_AAL/2015/page_15.pdf
# Added document with ID: Double_HWM/2016/page_52.pdf
# Added document with ID: Single_RSG/2016/page_69.pdf-1
# Added document with ID: Single_ETR/2008/page_267.pdf-3
# Added document with ID: Single_MAS/2010/page_29.pdf-3
# Added document with ID: Single_AAPL/2012/page_36.pdf-3
# Added document with ID: Single_LMT/2012/page_87.pdf-3
# Added document with ID: Single_LLY/2018/page_42.pdf-1
# Added document with ID: Single_GIS/2014/page_25.pdf-2
# Added document with ID: Single_FIS/2010/page_93.pdf-1
# Added document with ID: Single_AAPL/2011/page_38.pdf-2
# Added document with ID: Single_AMT/2004/page_28.pdf-1
# Added document with ID: Single_C/2009/page_48.pdf-1
# Added document with ID: Single_ALXN/2016/page_89.pdf-2
# Added document with ID: Single_IP/2006/page_19.pdf-2
# Added document with ID: Single_GS/2018/page_70.pdf-1
# Added document with ID: Single_HII/2011/page_69.pdf-3
# Added document with ID: Single_GPN/2015/page_82.pdf-4
# Added document with ID: Double_AAPL/2016/page_23.pdf
# Added document with ID: Double_MA/2008/page_116.pdf
# Added document with ID: Double_ETR/2016/page_315.pdf
# Added document with ID: Double_WRK/2019/page_31.pdf
# Added document with ID: Single_STT/2012/page_42.pdf-3
# Added document with ID: Double_OKE/2012/page_91.pdf
# Added document with ID: Single_IPG/2013/page_46.pdf-2
# Added document with ID: Single_LLY/2018/page_99.pdf-2
# Added document with ID: Single_AMT/2007/page_111.pdf-1
# Added document with ID: Single_CE/2014/page_32.pdf-2
# Added document with ID: Single_ABMD/2006/page_62.pdf-3
# Added document with ID: Single_ETFC/2015/page_27.pdf-1
# Added document with ID: Single_STT/2001/page_74.pdf-3
# Added document with ID: Single_LMT/2013/page_89.pdf-2
# Added document with ID: Double_VNO/2011/page_85.pdf
# Added document with ID: Single_GS/2012/page_89.pdf-3
# Added document with ID: Single_C/2008/page_193.pdf-3
# Added document with ID: Single_AAPL/2013/page_27.pdf-3
# Added document with ID: Single_IP/2013/page_61.pdf-1
# Added document with ID: Single_C/2016/page_333.pdf-3
# Added document with ID: Single_UNP/2009/page_25.pdf-4
# Added document with ID: Single_CE/2014/page_16.pdf-1
# Added document with ID: Double_AES/2010/page_133.pdf
# Added document with ID: Single_PNC/2011/page_208.pdf-1
# Added document with ID: Single_BLK/2008/page_75.pdf-2
# Added document with ID: Single_STT/2014/page_69.pdf-1
# Added document with ID: Single_SLG/2012/page_87.pdf-2
# Added document with ID: Single_MSI/2013/page_87.pdf-1
# Added document with ID: Single_UNP/2009/page_38.pdf-2
# Added document with ID: Single_UNP/2006/page_33.pdf-1
# Added document with ID: Double_MS/2013/page_240.pdf
# Added document with ID: Single_AMT/2004/page_91.pdf-2
# Added document with ID: Double_LMT/2014/page_46.pdf
# Added document with ID: Single_MAS/2010/page_29.pdf-1
# Added document with ID: Single_IP/2013/page_65.pdf-1
# Added document with ID: Double_BLL/2011/page_29.pdf
# Added document with ID: Single_STT/2013/page_107.pdf-2
# Added document with ID: Single_RE/2017/page_41.pdf-2
# Added document with ID: Single_EOG/2017/page_85.pdf-2
# Added document with ID: Single_AAPL/2011/page_24.pdf-1
# Added document with ID: Double_AON/2007/page_185.pdf
# Added document with ID: Double_PNC/2013/page_230.pdf
# Added document with ID: Single_GIS/2014/page_25.pdf-1
# Added document with ID: Single_JPM/2008/page_112.pdf-1
# Added document with ID: Double_VTR/2003/page_39.pdf
# Added document with ID: Single_GS/2018/page_212.pdf-2
# Added document with ID: Single_CME/2012/page_100.pdf-3
# Added document with ID: Double_OKE/2008/page_38.pdf
# Added document with ID: Single_LMT/2002/page_33.pdf-2
# Added document with ID: Double_GIS/2014/page_25.pdf
# Added document with ID: Single_AWK/2015/page_112.pdf-1
# Added document with ID: Single_GS/2017/page_104.pdf-1
# Added document with ID: Single_APTV/2016/page_47.pdf-2
# Added document with ID: Double_MS/2013/page_277.pdf
# Added document with ID: Single_MA/2008/page_116.pdf-1
# Added document with ID: Double_SLB/2009/page_46.pdf
# Added document with ID: Double_DRE/2008/page_29.pdf
# Added document with ID: Double_HUM/2017/page_45.pdf
# Added document with ID: Single_IPG/2018/page_39.pdf-1
# Added document with ID: Single_UNP/2008/page_83.pdf-4
# Added document with ID: Single_AAL/2014/page_92.pdf-3
# Added document with ID: Single_MAS/2012/page_86.pdf-1
# Added document with ID: Single_UNP/2008/page_26.pdf-3
# Added document with ID: Double_EW/2016/page_72.pdf
# Added document with ID: Single_UAA/2016/page_80.pdf-3
# Added document with ID: Single_UPS/2015/page_35.pdf-1
# Added document with ID: Double_DISH/2015/page_142.pdf
# Added document with ID: Double_GIS/2018/page_39.pdf
# Added document with ID: Single_ETR/2008/page_313.pdf-4
# Added document with ID: Single_MRO/2009/page_35.pdf-3
# Added document with ID: Single_ETR/2011/page_358.pdf-2
# Added document with ID: Double_AAL/2015/page_131.pdf
# Added document with ID: Single_MA/2009/page_112.pdf-2
# Added document with ID: Single_ETR/2016/page_17.pdf-3
# Added document with ID: Single_IP/2009/page_36.pdf-2
# Added document with ID: Single_ANET/2017/page_156.pdf-2
# Added document with ID: Double_SLG/2017/page_110.pdf
# Added document with ID: Single_MRO/2009/page_36.pdf-4
# Added document with ID: Single_CMCSA/2015/page_150.pdf-1
# Added document with ID: Double_AON/2010/page_100.pdf
# Added document with ID: Double_ETR/2016/page_24.pdf
# Added document with ID: Single_ADI/2010/page_82.pdf-2
# Added document with ID: Single_CDW/2013/page_36.pdf-2
# Added document with ID: Single_CME/2010/page_113.pdf-1
# Added document with ID: Single_ABMD/2009/page_85.pdf-3
# Added document with ID: Single_AAP/2016/page_96.pdf-2
# Added document with ID: Single_STT/2008/page_109.pdf-4
# Added document with ID: Double_ETR/2013/page_93.pdf
# Added document with ID: Single_ETR/2016/page_343.pdf-1
# Added document with ID: Double_PPG/2006/page_26.pdf
# Added document with ID: Single_HOLX/2008/page_93.pdf-2
# Added document with ID: Single_SNA/2007/page_47.pdf-2
# Added document with ID: Single_RE/2014/page_125.pdf-1
# Added document with ID: Single_BLK/2015/page_35.pdf-3
# Added document with ID: Single_AMT/2006/page_31.pdf-3
# Added document with ID: Double_AAPL/2007/page_83.pdf
# Added document with ID: Single_LMT/2012/page_43.pdf-2
# Added document with ID: Single_RE/2010/page_138.pdf-5
# Added document with ID: Double_PPG/2012/page_47.pdf
# Added document with ID: Single_GS/2012/page_177.pdf-1
# Added document with ID: Single_IP/2012/page_56.pdf-1
# Added document with ID: Single_AMT/2010/page_115.pdf-3
# Added document with ID: Double_C/2008/page_217.pdf
# Added document with ID: Single_HII/2011/page_103.pdf-1
# Added document with ID: Double_AMT/2010/page_118.pdf
# Added document with ID: Single_AAPL/2002/page_23.pdf-2
# Added document with ID: Single_BDX/2017/page_32.pdf-4
# Added document with ID: Single_CAG/2007/page_73.pdf-1
# Added document with ID: Double_AAPL/2013/page_27.pdf
# ...
# Added document with ID: Single_MA/2010/page_107.pdf-1
# Added document with ID: Single_MRO/2011/page_21.pdf-2
# Added document with ID: Single_UNP/2006/page_45.pdf-4
# Added document with ID: Single_MSI/2007/page_102.pdf-2
# Added document with ID: Double_JPM/2009/page_183.pdf
# Added document with ID: Single_MA/2009/page_115.pdf-1
# Added document with ID: Double_EOG/2017/page_85.pdf
# Added document with ID: Single_DVN/2014/page_88.pdf-2
# Added document with ID: Single_AMAT/2012/page_37.pdf-1
# Added document with ID: Single_ETR/2004/page_22.pdf-2
# Added document with ID: Single_C/2015/page_314.pdf-4
# Added document with ID: Double_AMT/2007/page_32.pdf
# Added document with ID: Single_PPG/2011/page_46.pdf-2
# Added document with ID: Single_CE/2017/page_20.pdf-3
# Added document with ID: Single_INTC/2016/page_43.pdf-1
# Added document with ID: Double_AWK/2018/page_148.pdf
# Added document with ID: Single_AMT/2008/page_96.pdf-3
# Added document with ID: Single_RCL/2005/page_40.pdf-4
# Added document with ID: Single_IP/2012/page_56.pdf-2
# Added document with ID: Single_AAPL/2007/page_70.pdf-3
# Added document with ID: Single_EW/2017/page_83.pdf-2
# Added document with ID: Single_LLY/2018/page_75.pdf-3
# Added document with ID: Single_GPN/2009/page_95.pdf-2
# Added document with ID: Double_RSG/2010/page_114.pdf
# Added document with ID: Single_UPS/2007/page_32.pdf-1
# Added document with ID: Single_GS/2014/page_134.pdf-4
# Added document with ID: Single_CB/2008/page_83.pdf-2
# Added document with ID: Double_MRK/2013/page_116.pdf
# Added document with ID: Single_ALLE/2017/page_29.pdf-1
# Added document with ID: Single_IP/2013/page_62.pdf-2
# Added document with ID: Single_BLK/2014/page_68.pdf-1
# Added document with ID: Single_ETR/2008/page_314.pdf-3
# Added document with ID: Single_ADBE/2003/page_111.pdf-1
# Added document with ID: Single_MAS/2018/page_73.pdf-1
# Added document with ID: Single_ETR/2015/page_18.pdf-3
# Added document with ID: Single_ETR/2008/page_401.pdf-3
# Added document with ID: Single_ABMD/2012/page_75.pdf-4
# Added document with ID: Single_JPM/2013/page_158.pdf-3
# Added document with ID: Single_IP/2012/page_55.pdf-1
# Added document with ID: Single_HFC/2011/page_92.pdf-6
# Added document with ID: Single_PNC/2012/page_96.pdf-1
# Added document with ID: Single_IPG/2014/page_37.pdf-3
# Added document with ID: Double_JPM/2010/page_187.pdf
# Added document with ID: Single_ETR/2008/page_337.pdf-1
# Added document with ID: Single_UNP/2006/page_62.pdf-3
# Added document with ID: Single_IPG/2018/page_104.pdf-3
# Added document with ID: Single_PNC/2011/page_74.pdf-1
# Added document with ID: Single_NTAP/2014/page_33.pdf-2
# Added document with ID: Single_UNP/2009/page_68.pdf-1
# Added document with ID: Single_BLK/2017/page_81.pdf-4
# Added document with ID: Single_AAPL/2012/page_71.pdf-3
# Added document with ID: Double_PM/2017/page_117.pdf
# Added document with ID: Single_IPG/2013/page_35.pdf-1
# Added document with ID: Single_AAPL/2006/page_79.pdf-3
# Added document with ID: Double_CAG/2007/page_41.pdf
# Added document with ID: Double_MS/2015/page_200.pdf
# Added document with ID: Single_LKQ/2010/page_81.pdf-1
# Added document with ID: Single_GS/2014/page_44.pdf-2
# Added document with ID: Single_GRMN/2008/page_98.pdf-2
# Added document with ID: Single_AMT/2002/page_74.pdf-1
# Added document with ID: Single_ORLY/2018/page_30.pdf-4
# Added document with ID: Single_AAPL/2012/page_36.pdf-1
# Added document with ID: Single_HFC/2017/page_103.pdf-4
# Added document with ID: Single_GPN/2008/page_95.pdf-3
# Added document with ID: Single_EW/2014/page_35.pdf-1
# Added document with ID: Single_BLK/2012/page_31.pdf-2
# Added document with ID: Single_LMT/2016/page_105.pdf-1
# Added document with ID: Single_HFC/2011/page_92.pdf-2
# Added document with ID: Single_UAA/2016/page_83.pdf-4
# Added document with ID: Single_SLB/2006/page_82.pdf-2
# Added document with ID: Double_DVN/2014/page_112.pdf
# Added document with ID: Single_ETR/2002/page_266.pdf-2
# Added document with ID: Double_AES/2011/page_261.pdf
# Added document with ID: Single_ZBH/2008/page_84.pdf-2
# Added document with ID: Single_SNA/2012/page_82.pdf-2
# Added document with ID: Single_RSG/2012/page_124.pdf-1
# Added document with ID: Single_ETR/2015/page_133.pdf-4
# Added document with ID: Single_CE/2010/page_150.pdf-1
# Added document with ID: Double_HII/2012/page_98.pdf
# Added document with ID: Double_ETR/2004/page_160.pdf
# Added document with ID: Double_PM/2015/page_103.pdf
# Added document with ID: Double_INTC/2013/page_71.pdf
# Added document with ID: Double_TFX/2017/page_48.pdf
# Added document with ID: Single_WRK/2018/page_106.pdf-1
# Added document with ID: Single_LMT/2016/page_50.pdf-4
# Added document with ID: Single_LMT/2013/page_81.pdf-3
# Added document with ID: Double_AWK/2018/page_152.pdf
# Added document with ID: Double_IP/2009/page_38.pdf
# Added document with ID: Single_HWM/2018/page_69.pdf-2
# Added document with ID: Single_ADI/2019/page_85.pdf-2
# Added document with ID: Single_AMT/2005/page_77.pdf-3
# Added document with ID: Double_PKG/2011/page_14.pdf
# Added document with ID: Single_DVN/2011/page_84.pdf-1
# Added document with ID: Double_CME/2017/page_57.pdf
# Added document with ID: Single_AWK/2014/page_45.pdf-2
# Added document with ID: Double_JPM/2003/page_35.pdf
# Added document with ID: Double_GIS/2018/page_83.pdf
# Added document with ID: Double_AWK/2015/page_115.pdf
# Added document with ID: Single_RCL/2014/page_80.pdf-2
# Added document with ID: Single_CAT/2017/page_113.pdf-3
# Added document with ID: Single_ADBE/2014/page_87.pdf-1
# Added document with ID: Single_UNP/2010/page_75.pdf-3
# Added document with ID: Single_CB/2008/page_217.pdf-2
# Added document with ID: Single_RE/2014/page_40.pdf-2
# Added document with ID: Double_IP/2013/page_61.pdf
# Added document with ID: Single_AMAT/2014/page_37.pdf-3
# Added document with ID: Single_RCL/2016/page_7.pdf-4
# Added document with ID: Single_LMT/2007/page_55.pdf-4
# Added document with ID: Double_IP/2012/page_57.pdf
# Added document with ID: Double_GS/2012/page_152.pdf
# Added document with ID: Double_JPM/2010/page_59.pdf
# Added document with ID: Single_C/2017/page_119.pdf-2
# Added document with ID: Single_ETR/2004/page_258.pdf-2
# Added document with ID: Double_KIM/2014/page_59.pdf
# Added document with ID: Single_PNC/2018/page_81.pdf-3
# Added document with ID: Single_VTR/2007/page_48.pdf-2
# Added document with ID: Single_ALLE/2018/page_121.pdf-2
# Added document with ID: Single_HWM/2016/page_119.pdf-1
# Added document with ID: Single_LKQ/2009/page_66.pdf-4
# Added document with ID: Single_ABMD/2015/page_93.pdf-2
# Added document with ID: Single_K/2012/page_44.pdf-2
# Added document with ID: Single_PPG/2011/page_46.pdf-3
# Added document with ID: Single_UNP/2009/page_68.pdf-2
# Added document with ID: Single_SWKS/2012/page_116.pdf-2
# Added document with ID: Single_JPM/2013/page_124.pdf-2
# Added document with ID: Single_HWM/2015/page_73.pdf-1
# Added document with ID: Single_GS/2016/page_186.pdf-4
# Added document with ID: Single_ANSS/2008/page_85.pdf-1
# Added document with ID: Single_ANSS/2012/page_92.pdf-2
# Added document with ID: Double_PM/2017/page_25.pdf
# Added document with ID: Double_ETR/2008/page_438.pdf
# Added document with ID: Single_AON/2010/page_61.pdf-3
# Added document with ID: Single_UAA/2016/page_81.pdf-3
# Added document with ID: Double_C/2010/page_69.pdf
# Added document with ID: Single_IPG/2017/page_49.pdf-1
# Added document with ID: Single_BLK/2017/page_77.pdf-1
# Added document with ID: Single_DRE/2009/page_36.pdf-2
# Added document with ID: Single_LLY/2008/page_39.pdf-1
# Added document with ID: Single_AWK/2017/page_128.pdf-2
# Added document with ID: Single_MRO/2011/page_37.pdf-1
# Added document with ID: Single_ETR/2011/page_22.pdf-2
# Added document with ID: Single_RCL/2011/page_16.pdf-3
# Added document with ID: Single_AON/2011/page_63.pdf-4
# Added document with ID: Double_GS/2018/page_175.pdf
# Added document with ID: Single_DVN/2010/page_70.pdf-1
# Added document with ID: Single_IP/2014/page_66.pdf-1
# Added document with ID: Double_BLK/2015/page_35.pdf
# Added document with ID: Single_GS/2013/page_145.pdf-2
# Added document with ID: Single_AMT/2005/page_84.pdf-3
# Added document with ID: Single_WRK/2018/page_53.pdf-3
# Added document with ID: Double_SNA/2007/page_47.pdf
# Added document with ID: Single_INTC/2016/page_43.pdf-2
# Added document with ID: Single_C/2017/page_119.pdf-4
# Added document with ID: Single_LMT/2015/page_53.pdf-2
# Added document with ID: Single_AON/2007/page_185.pdf-2
# Added document with ID: Single_AWK/2014/page_7.pdf-2
# Added document with ID: Double_AMT/2008/page_96.pdf
# Added document with ID: Single_ETR/2004/page_22.pdf-1
# Added document with ID: Double_EOG/2018/page_99.pdf
# Added document with ID: Double_AMT/2007/page_114.pdf
# Added document with ID: Single_PPG/2015/page_40.pdf-1
# Added document with ID: Single_GS/2014/page_172.pdf-3
# Added document with ID: Single_AES/2003/page_48.pdf-1
# Added document with ID: Single_ETR/2016/page_144.pdf-2
# Added document with ID: Single_INTC/2017/page_45.pdf-3
# Added document with ID: Double_HII/2018/page_64.pdf
# Added document with ID: Double_FIS/2017/page_14.pdf
# Added document with ID: Single_LMT/2016/page_52.pdf-3
# Added document with ID: Single_RCL/2016/page_7.pdf-3
# Added document with ID: Double_MKTX/2011/page_43.pdf
# Added document with ID: Single_D/2002/page_39.pdf-4
# Added document with ID: Single_GPN/2008/page_39.pdf-3
# Added document with ID: Single_AMT/2012/page_104.pdf-2
# Added document with ID: Single_PNC/2012/page_58.pdf-5
# Added document with ID: Single_AMAT/2015/page_14.pdf-1
# Added document with ID: Single_AMT/2004/page_102.pdf-4
# Added document with ID: Single_FIS/2007/page_102.pdf-1
# Added document with ID: Single_AON/2010/page_55.pdf-2
# Added document with ID: Double_GPN/2014/page_71.pdf
# Added document with ID: Double_ETR/2011/page_435.pdf
# Added document with ID: Single_AES/2003/page_112.pdf-2
# Added document with ID: Single_ADI/2016/page_79.pdf-2
# Added document with ID: Single_RCL/2010/page_81.pdf-3
# Added document with ID: Double_AES/2016/page_45.pdf
# Added document with ID: Single_EXR/2005/page_46.pdf-2
# Added document with ID: Double_ZBH/2015/page_63.pdf
# Added document with ID: Single_ORLY/2015/page_28.pdf-2
# Added document with ID: Single_GPN/2014/page_71.pdf-4
# Added document with ID: Single_UNP/2012/page_55.pdf-1
# Added document with ID: Double_LLY/2018/page_75.pdf
# Added document with ID: Double_ETR/2011/page_359.pdf
# Added document with ID: Single_GIS/2008/page_83.pdf-2
# Added document with ID: Double_AMT/2012/page_123.pdf
# Added document with ID: Single_PPG/2011/page_28.pdf-2
# Added document with ID: Single_AAL/2015/page_51.pdf-4
# Added document with ID: Single_PNC/2016/page_155.pdf-1
# Added document with ID: Single_IPG/2009/page_67.pdf-3
# Added document with ID: Single_UNP/2006/page_45.pdf-2
# Added document with ID: Single_AWK/2015/page_110.pdf-3
# Added document with ID: Single_ADBE/2011/page_101.pdf-4
# Added document with ID: Single_C/2008/page_113.pdf-2
# Added document with ID: Single_CDW/2014/page_93.pdf-2
# Added document with ID: Single_PNC/2012/page_96.pdf-4
# Added document with ID: Single_AAL/2015/page_74.pdf-2
# Added document with ID: Single_AMT/2010/page_118.pdf-2
# Added document with ID: Single_LMT/2013/page_45.pdf-3
# Added document with ID: Double_GS/2016/page_161.pdf
# Added document with ID: Double_C/2015/page_73.pdf
# Added document with ID: Single_ETR/2008/page_267.pdf-2
# Added document with ID: Single_LMT/2014/page_85.pdf-1
# Added document with ID: Single_RCL/2011/page_16.pdf-2
# Added document with ID: Single_APTV/2015/page_50.pdf-1
# Added document with ID: Single_MAS/2012/page_92.pdf-1
# Added document with ID: Double_JPM/2018/page_149.pdf
# Added document with ID: Single_AWK/2018/page_162.pdf-4
# Added document with ID: Single_STT/2006/page_96.pdf-1
# Added document with ID: Single_TFX/2006/page_50.pdf-1
# Added document with ID: Single_ETR/2013/page_14.pdf-2
# Added document with ID: Single_UA/2011/page_70.pdf-2
# Added document with ID: Single_LMT/2014/page_49.pdf-3
# Added document with ID: Single_RE/2010/page_42.pdf-4
# Added document with ID: Double_FIS/2012/page_46.pdf
# Added document with ID: Single_CME/2010/page_104.pdf-2
# Added document with ID: Single_UNP/2009/page_61.pdf-2
# Added document with ID: Double_IPG/2014/page_23.pdf
# Added document with ID: Single_DRE/2016/page_64.pdf-4
# Added document with ID: Single_CME/2017/page_99.pdf-2
# Added document with ID: Single_AES/2003/page_93.pdf-3
# Added document with ID: Double_BLL/2010/page_39.pdf
# Added document with ID: Single_BLL/2007/page_46.pdf-4
# Added document with ID: Single_JPM/2003/page_44.pdf-1
# Added document with ID: Double_AAPL/2011/page_37.pdf
# Added document with ID: Double_CE/2009/page_121.pdf
# Added document with ID: Single_PNC/2011/page_183.pdf-4
# Added document with ID: Single_DISH/2014/page_64.pdf-4
# Added document with ID: Single_JKHY/2009/page_28.pdf-4
# Added document with ID: Single_INTC/2017/page_45.pdf-1
# Added document with ID: Single_AMT/2007/page_99.pdf-3
# Added document with ID: Double_REGN/2010/page_72.pdf
# Added document with ID: Single_AAPL/2007/page_117.pdf-1
# Added document with ID: Single_MO/2017/page_79.pdf-2
# Added document with ID: Single_BLL/2011/page_29.pdf-2
# Added document with ID: Double_VTR/2007/page_97.pdf
# Added document with ID: Single_HII/2018/page_64.pdf-2
# Added document with ID: Single_SNPS/2009/page_59.pdf-1
# Added document with ID: Double_IPG/2009/page_67.pdf
# Added document with ID: Double_IPG/2018/page_52.pdf
# Added document with ID: Single_PNC/2013/page_102.pdf-1
# Added document with ID: Single_UNP/2010/page_55.pdf-3
# Added document with ID: Double_GS/2012/page_154.pdf
# Added document with ID: Single_PPG/2013/page_54.pdf-4
# Added document with ID: Single_BLK/2013/page_123.pdf-3
# Added document with ID: Double_VNO/2011/page_187.pdf
# Added document with ID: Single_ETR/2017/page_343.pdf-1
# Added document with ID: Single_UPS/2017/page_31.pdf-2
# Added document with ID: Single_IP/2009/page_72.pdf-4
# Added document with ID: Single_VRTX/2006/page_121.pdf-2
# Added document with ID: Double_AMT/2004/page_76.pdf
# Added document with ID: Single_OKE/2012/page_91.pdf-2
# Added document with ID: Single_MAS/2013/page_27.pdf-4
# Added document with ID: Single_C/2018/page_288.pdf-1
# Added document with ID: Single_JPM/2014/page_198.pdf-2
# Added document with ID: Single_PPG/2005/page_24.pdf-2
# Added document with ID: Double_BKR/2017/page_105.pdf
# Added document with ID: Single_RSG/2017/page_98.pdf-1
# Added document with ID: Single_EW/2004/page_83.pdf-2
# Added document with ID: Double_JPM/2017/page_144.pdf
# Added document with ID: Single_KMI/2010/page_164.pdf-4
# Added document with ID: Single_KIM/2014/page_131.pdf-1
# Added document with ID: Double_C/2018/page_53.pdf
# Added document with ID: Single_UPS/2013/page_34.pdf-2
# Added document with ID: Single_IP/2012/page_57.pdf-3
# Added document with ID: Single_ADBE/2012/page_102.pdf-2
# Added document with ID: Single_D/2002/page_39.pdf-3
# Added document with ID: Single_PNC/2014/page_84.pdf-3
# Added document with ID: Single_SLB/2009/page_65.pdf-2
# Added document with ID: Single_AMAT/2012/page_37.pdf-3
# Added document with ID: Single_AWK/2014/page_122.pdf-2
# Added document with ID: Double_ETR/2002/page_266.pdf
# Added document with ID: Double_UNP/2012/page_29.pdf
# Added document with ID: Single_MO/2017/page_65.pdf-2
# Added document with ID: Single_APD/2014/page_36.pdf-1
# Added document with ID: Double_HIG/2013/page_235.pdf
# Added document with ID: Single_CAT/2018/page_38.pdf-1
# Added document with ID: Double_VNO/2003/page_97.pdf
# Added document with ID: Double_LMT/2017/page_101.pdf
# Added document with ID: Single_STT/2006/page_92.pdf-2
# Added document with ID: Single_ETFC/2007/page_135.pdf-1
# Added document with ID: Double_MRO/2018/page_96.pdf
# Added document with ID: Single_IP/2012/page_64.pdf-1
# Added document with ID: Single_ETR/2008/page_313.pdf-2
# Added document with ID: Single_HII/2012/page_86.pdf-1
# Added document with ID: Double_WRK/2018/page_56.pdf
# Added document with ID: Single_CB/2009/page_81.pdf-1
# Added document with ID: Double_AWK/2017/page_128.pdf
# Added document with ID: Double_IPG/2015/page_24.pdf
# Added document with ID: Single_CDW/2017/page_56.pdf-2

# %%
import os
import openai
import numpy as np
import faiss
import hashlib
import pickle
import logging
from datetime import datetime
from neo4j import GraphDatabase
from langchain_community.chat_models import ChatOpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv
from tenacity import retry, stop_after_attempt, wait_random_exponential
from concurrent.futures import ThreadPoolExecutor, as_completed

# Load environment variables and set up logging
load_dotenv()
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

class Neo4jHandler:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def get_all_documents(self):
        with self.driver.session() as session:
            result = session.read_transaction(self._get_all_documents)
            return result

    @staticmethod
    def _get_all_documents(tx):
        query = """
        MATCH (d:Document)
        MATCH (d)-[:HAS_PRE_TEXT]->(p:PreText)
        MATCH (d)-[:HAS_POST_TEXT]->(po:PostText)
        OPTIONAL MATCH (d)-[:HAS_TABLE]->(t:Table)
        RETURN d.id AS id, p.content AS pre_text, po.content AS post_text, 
               p.embedding AS emb_pre, po.embedding AS emb_post, 
               collect(t.content) AS tables
        """
        result = tx.run(query)
        return [(record["id"], record["pre_text"], record["post_text"], 
                 record["emb_pre"], record["emb_post"], record["tables"]) 
                for record in result]

@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(5))
def get_embedding_with_retry(text, model="text-embedding-3-small"):
    try:
        response = openai.Embedding.create(input=[text], model=model)
        return response['data'][0]['embedding']
    except Exception as e:
        logger.error(f"Error getting embedding: {e}")
        raise

def get_embedding_with_cache(text, model="text-embedding-3-small"):
    text_hash = hashlib.md5(text.encode()).hexdigest()
    cache_file = f"embedding_cache/{text_hash}.pkl"

    try:
        with open(cache_file, "rb") as f:
            return pickle.load(f)
    except FileNotFoundError:
        embedding = get_embedding_with_retry(text, model)
        
        os.makedirs("embedding_cache", exist_ok=True)
        with open(cache_file, "wb") as f:
            pickle.dump(embedding, f)
        
        return embedding

def normalize_embeddings(embeddings):
    norms = np.linalg.norm(embeddings, axis=1, keepdims=True)
    return embeddings / norms

def process_documents_in_batches(documents, batch_size=1000):
    for i in range(0, len(documents), batch_size):
        yield documents[i:i+batch_size]

def index_embeddings_batched(documents):
    emb_pre_list = []
    emb_post_list = []
    
    for batch in process_documents_in_batches(documents):
        emb_pre = np.array([doc[3] for doc in batch]).astype('float32')
        emb_post = np.array([doc[4] for doc in batch]).astype('float32')
        emb_pre = normalize_embeddings(emb_pre)
        emb_post = normalize_embeddings(emb_post)
        emb_pre_list.append(emb_pre)
        emb_post_list.append(emb_post)
    
    emb_pre_all = np.concatenate(emb_pre_list)
    emb_post_all = np.concatenate(emb_post_list)
    
    index_pre = faiss.IndexFlatIP(emb_pre_all.shape[1])
    index_post = faiss.IndexFlatIP(emb_post_all.shape[1])
    index_pre.add(emb_pre_all)
    index_post.add(emb_post_all)
    return index_pre, index_post

def find_similar_documents(query, index_pre, index_post, documents, top_k=20):
    query_embedding = np.array(get_embedding_with_cache(query)).astype('float32').reshape(1, -1)
    query_embedding = normalize_embeddings(query_embedding)
    distances_pre, indices_pre = index_pre.search(query_embedding, top_k)
    distances_post, indices_post = index_post.search(query_embedding, top_k)
    
    combined_results = {}
    for i in range(top_k):
        doc_id_pre = indices_pre[0][i]
        doc_id_post = indices_post[0][i]
        combined_results[doc_id_pre] = combined_results.get(doc_id_pre, 0) + distances_pre[0][i]
        combined_results[doc_id_post] = combined_results.get(doc_id_post, 0) + distances_post[0][i]
    
    sorted_results = sorted(combined_results.items(), key=lambda item: item[1], reverse=True)[:top_k]
    return [(documents[i][0], documents[i][1], documents[i][2], documents[i][5], score) for i, score in sorted_results]

def re_rank_documents_parallel(question, documents, max_workers=5):
    llm = ChatOpenAI(api_key=os.getenv('OPENAI_API_KEY'), model="gpt-4o-mini", temperature=0)
    prompt_template = PromptTemplate(
        input_variables=["question", "document"],
        template="Question: {question}\n\nDocument: {document}\n\nOn a scale of 0 to 10, how relevant is this document to the question? Provide only a numerical score:"
    )
    rank_chain = LLMChain(llm=llm, prompt=prompt_template)

    def process_document(doc):
        doc_id, pre_text, post_text, tables, score = doc
        document_text = f"Pre Text: {pre_text}\nPost Text: {post_text}\nTables: {tables}"
        relevance_score = rank_chain.run({"question": question, "document": document_text})
        try:
            relevance_score = float(relevance_score.strip())
        except ValueError:
            relevance_score = 0.0
        return (doc_id, pre_text, post_text, tables, relevance_score)

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_doc = {executor.submit(process_document, doc): doc for doc in documents}
        ranked_docs = []
        for future in as_completed(future_to_doc):
            ranked_docs.append(future.result())

    ranked_docs = sorted(ranked_docs, key=lambda x: x[4], reverse=True)
    return ranked_docs[:10]

def prepare_context(top_docs, max_tokens=10000):
    context = ""
    current_tokens = 0
    for doc_id, pre_text, post_text, tables, score in top_docs:
        doc_context = f"Document ID: {doc_id}\nPre Text: {pre_text}\nPost Text: {post_text}\nTables: {tables}\n\n"
        doc_tokens = len(doc_context.split())
        if current_tokens + doc_tokens > max_tokens:
            break
        context += doc_context
        current_tokens += doc_tokens  
    return context



def answer_question_with_context(question, context):
    llm = ChatOpenAI(api_key=os.getenv('OPENAI_API_KEY'), model="gpt-4o-mini", temperature=0)

    prompt_template = PromptTemplate(
        input_variables=["context", "question"],
        template="""
Context: {context}

Given the context, {question} Report your answer using the following format:

Formatted answer: Float number to two decimal point precision 

Answer:
"""
    )

    qa_chain = LLMChain(llm=llm, prompt=prompt_template)

    answer = qa_chain.run({"context": context, "question": question})
    return answer

def qa_system(question):
    logger.info(f"Processing question: {question}")
    
    neo4j_handler = Neo4jHandler("bolt://localhost:7687", "neo4j", "12345678")
    openai.api_key = os.getenv('OPENAI_API_KEY')

    documents = neo4j_handler.get_all_documents()
    logger.info(f"Retrieved {len(documents)} documents from Neo4j")

    index_pre, index_post = index_embeddings_batched(documents)
    logger.info("Indexed embeddings using FAISS")

    similar_docs = find_similar_documents(question, index_pre, index_post, documents)
    logger.info(f"Found {len(similar_docs)} similar documents")

    top_docs = re_rank_documents_parallel(question, similar_docs)
    logger.info(f"Re-ranked top 5 documents: {[doc[0] for doc in top_docs]}")

    context = prepare_context(top_docs)
    logger.info(f"Prepared context with {len(context.split())} words")

    answer = answer_question_with_context(question, context)
    logger.info("Generated answer using GPT-4o-mini")

    neo4j_handler.close()

    return context, answer

if __name__ == "__main__":
    question = "What was the percentage change in the net cash from operating activities from 2008 to 2009?"
    context, answer = qa_system(question)
    print(f"Question: {question}\n")
    print(answer)
# Out:
# 2024-09-23 12:01:59,115 - INFO - Processing question: What was the percentage change in the net cash from operating activities from 2008 to 2009?
# /var/folders/1b/lp9bmlcs1419x2rb003z9n180000gn/T/ipykernel_91940/2800590932.py:31: DeprecationWarning: read_transaction has been renamed to execute_read
#   result = session.read_transaction(self._get_all_documents)
# 2024-09-23 12:02:03,857 - INFO - Retrieved 3037 documents from Neo4j
# 2024-09-23 12:02:04,161 - INFO - Indexed embeddings using FAISS
# 2024-09-23 12:02:04,165 - INFO - Found 20 similar documents
# 2024-09-23 12:02:06,748 - INFO - Re-ranked top 5 documents: ['Single_UNP/2009/page_38.pdf-3', 'Single_UNP/2009/page_38.pdf-4', 'Single_UNP/2009/page_38.pdf-2', 'Single_SWKS/2010/page_105.pdf-3', 'Single_SWKS/2010/page_105.pdf-1', 'Single_SWKS/2010/page_105.pdf-2', 'Double_UNP/2011/page_35.pdf', 'Single_GIS/2018/page_39.pdf-1', 'Double_GIS/2018/page_39.pdf', 'Single_GIS/2018/page_39.pdf-2']
# 2024-09-23 12:02:06,751 - INFO - Prepared context with 5211 words
# 2024-09-23 12:02:11,037 - INFO - Generated answer using GPT-4o-mini
# Question: What was the percentage change in the net cash from operating activities from 2008 to 2009?
#
# To calculate the percentage change in net cash from operating activities from 2008 to 2009, we can use the formula:
#
# \[
# \text{Percentage Change} = \left( \frac{\text{New Value} - \text{Old Value}}{\text{Old Value}} \right) \times 100
# \]
#
# From the provided data:
# - Cash provided by operating activities in 2008: $4,070 million
# - Cash provided by operating activities in 2009: $3,234 million
#
# Now, substituting the values into the formula:
#
# \[
# \text{Percentage Change} = \left( \frac{3,234 - 4,070}{4,070} \right) \times 100
# \]
#
# Calculating the difference:
#
# \[
# 3,234 - 4,070 = -836
# \]
#
# Now, substituting back into the formula:
#
# \[
# \text{Percentage Change} = \left( \frac{-836}{4,070} \right) \times 100 \approx -20.54
# \]
#
# Thus, the percentage change in net cash from operating activities from 2008 to 2009 is approximately -20.54%.
#
# Formatted answer: -20.54
